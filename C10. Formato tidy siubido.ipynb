# %% [markdown]
# <img src="logo.png">

# %%
import pandas as pd
import numpy as np
from siuba import *
import os 

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# La siguiente tabla representa el número de medallas obtenidas en JJOO por Estados Uniddos, China y Gran Bretaña diseminados por sexo y año:
#
# | país          | año | mujeres | hombres |
# |---------------|-----|---------|---------|
# | Estados Unidos| 2020| 66      | 47      |
# | China         | 2020| 37      | 32      |
# | Gran Bretaña  | 2020| 38      | 26      |
# | Estados Unidos| 2016| 61      | 60      |
# | China         | 2016| 26      | 18      |
# | Gran Bretaña  | 2016| 27      | 23      |
# | Estados Unidos| 2012| 58      | 46      |
# | China         | 2012| 38      | 27      |
# | Gran Bretaña  | 2012| 29      | 17      |
# | Estados Unidos| 2008| 48      | 36      |
# | China         | 2008| 34      | 38      |
# | Gran Bretaña  | 2008| 25      | 19      |
#
# Puedes encontrar dicha tabla en nuestro repositorio con el nombre de **medallero_olimpico_no_tidy.csv**

# %% [markdown]
# Supongamos que queremos conocer el total de medallas obtenidas por país y sexo en total.
#
# ```python
#
# medallero_no_tidy = pd.read_csv("medallero_olimpico_no_tidy.csv",}
#                                 encoding="latin1")
#
# (
# medallero_no_tidy >> group_by(_.pais) >>
#     summarize(tot_mujeres = _.mujeres.sum(),tot_hombres = _.hombres.sum())
# )
#
# ```

# %%
## queremos conocer el total de medallas obtenidas por país y sexo en total.

os.chdir("C:\\Users\\Usuario\\Documents\\scidata\\24_cdd_py\\practicas\\medallero")
medallero_no_tidy = pd.read_csv("medallero_olimpico_no_tidy.csv",
                                encoding="latin1")

medallero_no_tidy
# Out:
#               pais  anio  mujeres  hombres
# 0   Estados Unidos  2020       66       47
# 1            China  2020       37       32
# 2     Gran Bretaña  2020       38       26
# 3   Estados Unidos  2016       61       60
# 4            China  2016       26       18
# 5     Gran Bretaña  2016       27       23
# 6   Estados Unidos  2012       58       46
# 7            China  2012       38       27
# 8     Gran Bretaña  2012       29       17
# 9   Estados Unidos  2008       48       36
# 10           China  2008       34       38
# 11    Gran Bretaña  2008       25       19

# %%
(
medallero_no_tidy >> group_by(_.pais) >> summarize(medallas_mujeres = _.mujeres.sum(),
                                                   medallas_hombres = _.hombres.sum())
)
# Out:
#              pais  medallas_mujeres  medallas_hombres
# 0           China               135               115
# 1  Estados Unidos               233               189
# 2    Gran Bretaña               119                85

# %%
medallero_no_tidy = pd.read_csv("C:\\Users\\Usuario\\Documents\\scidata\\24_cdd_py\\practicas\\medallero\\medallero_olimpico_no_tidy.csv",
                                encoding="latin1")

(
medallero_no_tidy >> group_by(_.pais) >> 
    summarize(medallas_mujeres = _.mujeres.sum(),
              medallas_hombres = _.hombres.sum())
)

#medallero_ordenado >> group_by(_.pais,_.sexo) >> summarize(total_medallas = _.medallas.sum())
# Out:
#              pais  medallas_mujeres  medallas_hombres
# 0           China               135               115
# 1  Estados Unidos               233               189
# 2    Gran Bretaña               119                85

# %% [markdown]
# | 2019 | físicos     | 15669                  | 32455                    | 757971                                     | 30303                   | 5925                                     | 553174            | 98191     | 11806   | 1477216  | 57322                                    |
# | 2019 | emocionales | 158865                 | 296211                   | 4271726                                    | 769020                  | 84911                                    | 4670606           | 7585692   | 376224  | 1080585  | 1490632                                  |
# | 2019 | laborales   | 19793                  | 17913                    | 104021                                     | 15828                   | 3073                                     | 107460            | 118455    | 32359   | 12419    | 23615                                    |
# | 2019 | ninguno     | 61796                  | 291486                   | 1026535                                    | 815445                  | 16836                                    | 2444534           | 6017582   | 564338  | 264779   | 475398                                   |
# | 2020 | económicos  | 759576                 | 3162751                  | 6033612                                    | 2180091                 | 514888                                  | 137040            | 498470    | 3090792 | 106042   | 37688                                    |
# | 2020 | físicos     | 13167                  | 23188                    | 531356                                     | 25972                   | 4834                                     | 411960            | 79479     | 9158    | 1070545  | 51761                                    |
# | 2020 | emocionales | 123973                 | 211051                   | 3428746                                    | 573858                  | 62543                                    | 3627942           | 5836046   | 296675  | 842286   | 1237685                                  |
# | 2020 | laborales   | 15902                  | 10110                    | 67445                                      | 11138                   | 2401                                     | 71961             | 65479     | 22168   | 9948     | 18612                                    |
# | 2020 | ninguno     | 46601                  | 185347                   | 676495                                     | 552688                  | 12804                                    | 1902321           | 4779611   | 399795  | 169189   | 328631                                   |
# | 2021 | económicos  | 729044                 | 3443061                  | 6451580                                    | 2185914                 | 543586                                  | 161768            | 571232    | 3122114 | 111496   | 36798                                    |
# | 2021 | físicos     | 12132                  | 29129                    | 603867                                     | 29491                   | 5530                                     | 418372            | 102678    | 12324   | 1192138  | 54996                                    |
# | 2021 | emocionales | 121502                 | 223914                   | 3533384                                    | 629696                  | 73164                                    | 3837964           | 6119188   | 347180  | 937157   | 1341074                                  |
# | 2021 | laborales   | 16932                  | 14422                    | 84112                                      | 14480                   | 3277                                     | 84318             | 88782     | 32164   | 11328    | 22533                                    |
# | 2021 | ninguno     | 52556                  | 201720                   | 789733                                     | 624057                  | 18755                                    | 2061314           | 5301079   | 473201  | 191032   | 439691                                   |

# %% [markdown]
# ```python
# danios_no_tidy = pd.read_csv("danios_no_tidy.csv",encoding="latin1")
#
# (
# danios_no_tidy >>
#     group_by(_.daño) >>
#     summarize(Robo_total_de_vehículo = _.Robo_total_de_vehículo.sum(),
#               Robo_parcial_de_vehículo = _.Robo_parcial_de_vehículo.sum(),
#               Robo_o_asalto_en_calle_o_transporte_público = _.Robo_o_asalto_en_calle_o_transporte_público.sum(),
#               Robo_en_forma_distinta_a_las_anteriores = _.Robo_en_forma_distinta_a_las_anteriores.sum(),
#               Amenazas_verbales = _.Amenazas_verbales.sum(),
#               Extorsión = _.Extorsión.sum(),
#               Fraude = _.Fraude.sum(),
#               Lesiones = _.Lesiones.sum(),
#               Otros_delitos_distintos_a_los_anteriores = _.Otros_delitos_distintos_a_los_anteriores.sum()
#               )
# )
# ```

# %%
# 2     81552    278066                                    591925
# 3     13858      4638                                      9915
# 4    198438     83722                                    130783
# 5   2766280     54742                                     76463
# 6      4397    626885                                     49667
# 7    134688    291348                                    704641
# 8      8349      5067                                     14930
# 9    251048     59625                                    108923
# 10  2829875     68379                                     44220
# 11     4408    694426                                     68455
# 12   246474    294672                                    688470
# 13     5211     12451                                      6958
# 14   347009     88617                                    169744
# 15  2705964     56480                                     48721
# 16     4195    577536                                     39024
# 17   101763    269076                                    604128
# 18    10613      6910                                      5990
# 19   397477    158547                                    160696
# 20  3344383     55889                                     79486
# 21     2347    633136                                     35886
# 22   138267    189707                                    745453
# 23    11101      5002                                      5976
# 24   403519     83119                                    195966
# 25  3817174     64554                                     72221
# 26     4999    584461                                     43753
# 27   156323    219446                                   1143883
# 28     3902      8450                                     10610
# 29   569648    126262                                    191568
# 30  3932071     84504                                    104456
# 31    11202    557825                                     42822
# 32   198199    265883                                   1231768
# 33    10062      9647                                     26471
# 34   544447    114200                                    195251
# 35  3738260     77748                                     93156
# 36     8298    676391                                     93928
# 37   195354    252820                                   2261494
# 38     6106      6393                                     17203
# 39   614277     89105                                    205557
# 40  4511978     52864                                     80081
# 41     3894    511128                                     72402
# 42   180819    277731                                   1408012
# 43     4234      2000                                     19433
# 44   622741     84748                                    209296
# 45  4475073     40667                                     56052
# 46     4248    610737                                     90691
# 47   186592    286704                                   1797129
# 48     3993      2899                                     19186
# 49   712256     63571                                    265076
# 50  4512056     72285                                     89172
# 51    11944    525216                                    127401
# 52   187302    312497                                   1610961
# 53     2922      9661                                     12536
# 54   670952     97872                                    224169

# %%
danios_no_tidy >> group_by(_.daño) >> summarize(Robo_total_de_vehículo = _.Robo_total_de_vehículo.sum(),
                                                Robo_parcial_de_vehículo = _.Robo_parcial_de_vehículo.sum(),
                                                Robo_o_asalto_en_calle_o_transporte_público = _.Robo_o_asalto_en_calle_o_transporte_público.sum(),
                                                Robo_en_forma_distinta_a_las_anteriores = _.Robo_en_forma_distinta_a_las_anteriores.sum(),
                                                Amenazas_verbales = _.Amenazas_verbales.sum(),
                                                Extorsión = _.Extorsión.sum(),
                                                Fraude = _.Fraude.sum(),
                                                Lesiones = _.Lesiones.sum(),
                                                Otros_delitos_distintos_a_los_anteriores = _.Otros_delitos_distintos_a_los_anteriores.sum()
                                                )
# Out:
#           daño  Robo_total_de_vehículo  Robo_parcial_de_vehículo  \
# 0   económicos                 4980934                  30594590
# 1  emocionales                  561746                    770891
# 2      físicos                   76766                     98950
# 3    laborales                   66489                    137730
# 4      ninguno                  276453                    816156
#
#    Robo_o_asalto_en_calle_o_transporte_público  \
# 0                                     67259205
# 1                                     13876910
# 2                                      2647456
# 3                                       329152
# 4                                      4046268
#
#    Robo_en_forma_distinta_a_las_anteriores  Amenazas_verbales  Extorsión  \
# 0                                 11495963            1578820    4335182
# 1                                  1039305           17194343   29092702
# 2                                    69647            2122227     316040
# 3                                   111021             439175     184284
# 4                                   855193            9033950   33491031
#
#      Fraude  Lesiones  Otros_delitos_distintos_a_los_anteriores
# 0  38957751    690871                                    796250
# 1   1807333   2937950                                  12787864
# 2     62898   6654736                                    695431
# 3     80351     73118                                    149208
# 4   5331812   1049388                                   2057029

# %% [markdown]
# La manera en que vienen presentadas las tablas **medallero_olimpico_no_tidy.csv** y **danios_no_tidy.csv** es lo que se conoce como formato gordo, formato desordenado o formato no tidy.
#
# En general, este tipo de formato no es compatible con la filosofía de siuba, donde es preferible tener tablas *largas* u *ordenadas*, o lo que se conoce como **formato tidy**:
#
# | país           | año | sexo    | medallas |
# |----------------|-----|---------|----------|
# | Estados Unidos | 2008 | mujeres | 48       |
# | Estados Unidos | 2008 | hombres | 36       |
# | China          | 2008 | mujeres | 34       |
# | China          | 2008 | hombres | 38       |
# | Gran Bretaña   | 2008 | mujeres | 25       |
# | Gran Bretaña   | 2008 | hombres | 19       |
# | Estados Unidos | 2012 | mujeres | 58       |
# | Estados Unidos | 2012 | hombres | 46       |
# | China          | 2012 | mujeres | 38       |
# | China          | 2012 | hombres | 27       |
# | Gran Bretaña   | 2012 | mujeres | 29       |
# | Gran Bretaña   | 2012 | hombres | 17       |
# | Estados Unidos | 2016 | mujeres | 61       |
# | Estados Unidos | 2016 | hombres | 60       |
# | China          | 2016 | mujeres | 26       |
# | China          | 2016 | hombres | 18       |
# | Gran Bretaña   | 2016 | mujeres | 27       |
# | Gran Bretaña   | 2016 | hombres | 23       |
# | Estados Unidos | 2020 | mujeres | 66       |
# | Estados Unidos | 2020 | hombres | 47       |
# | China          | 2020 | mujeres | 37       |
# | China          | 2020 | hombres | 32       |
# | Gran Bretaña   | 2020 | mujeres | 38       |
# | Gran Bretaña   | 2020 | hombres | 26       |

# %%
os.chdir("C:\\Users\\Usuario\\Documents\\scidata\\24_cdd_py\\practicas\\medallero")
medallero_ordenado = pd.read_csv("medallero_olimpico_ordenado.csv",
                                encoding="latin1")
medallero_ordenado
# Out:
#               pais  anio     sexo  medallas
# 0   Estados Unidos  2008  mujeres        48
# 1   Estados Unidos  2008  hombres        36
# 2            China  2008  mujeres        34
# 3            China  2008  hombres        38
# 4     Gran Bretaña  2008  mujeres        25
# 5     Gran Bretaña  2008  hombres        19
# 6   Estados Unidos  2012  mujeres        58
# 7   Estados Unidos  2012  hombres        46
# 8            China  2012  mujeres        38
# 9            China  2012  hombres        27
# 10    Gran Bretaña  2012  mujeres        29
# 11    Gran Bretaña  2012  hombres        17
# 12  Estados Unidos  2016  mujeres        61
# 13  Estados Unidos  2016  hombres        60
# 14           China  2016  mujeres        26
# 15           China  2016  hombres        18
# 16    Gran Bretaña  2016  mujeres        27
# 17    Gran Bretaña  2016  hombres        23
# 18  Estados Unidos  2020  mujeres        66
# 19  Estados Unidos  2020  hombres        47
# 20           China  2020  mujeres        37
# 21           China  2020  hombres        32
# 22    Gran Bretaña  2020  mujeres        38
# 23    Gran Bretaña  2020  hombres        26

# %%
medallero_ordenado >> group_by(_.pais,_.sexo) >> summarize(total_medallas = _.medallas.sum())
# Out:
#              pais     sexo  total_medallas
# 0           China  hombres             115
# 1           China  mujeres             135
# 2  Estados Unidos  hombres             189
# 3  Estados Unidos  mujeres             233
# 4    Gran Bretaña  hombres              85
# 5    Gran Bretaña  mujeres             119

# %% [markdown]
# Y ahora, aunque la tabla es más difícil de leer para nosotros, está mucho más organizada para hacer analizarla. La puedes encontrar en nuestro repositorio de datos con el nombre de **medallero_olimpico_ordenado.csv**
#
# ```python
#
# medallero_tidy = pd.read_csv("medallero_olimpico_tidy.csv")
#
# (
# medallero_tidy >>
#     group_by(_.pais,_.sexo) >>
#     summarize(total = _.medallas.sum())
# )
# ```

# %%
medallero_ordenado = pd.read_csv("C:\\Users\\Usuario\\Documents\\scidata\\24_cdd_py\\practicas\\medallero\\medallero_olimpico_tidy.csv",
                             encoding="latin1")

(
medallero_ordenado >> 
    group_by(_.pais,_.sexo) >> 
    summarize(total = _.medallas.sum())
)

# %% [markdown]
# Ahora bien, en caso de estar en la situación de tener una tabla en formato ancho nos va a interesar pasar a formato largo.
#
# Contamos con las función ``pd.melt`` que tiene la siguiente sintaxis:
#
# ```python
# ################################################################
# #######    En Python     #######################################
# ################################################################
#
# import pandas as pd
#
# pd.melt(frame=tabla, #es la tabla no ordenada
#      id_vars=["col1","col2",...],  #columnas que quieres mantener
#      value_vars=["col3","col4",...], #columnas que quieres ordenar
#      var_name="variable", #nombre de la nueva columna donde se colocarán los nombres de las columnas antiguas
#      value_name="value") #nombre de la nueva columna donde se colocarán los valores correspondientes a las columnas antiguas
# ```

# %% [markdown]
# Por lo tanto, en nuestro caso particular del medallero olímpico desordenado tenemos:
#
# ```python
# medallero_tidy = pd.melt(frame=medallero_no_tidy,
#                          id_vars=["pais", "anio"],
#                          value_vars=["hombres", "mujeres"],
#                          var_name="sexo",
#                          value_name="medallas")
# ```

# %%
medallero_tidy = pd.melt(frame=medallero_no_tidy, 
                         id_vars=["pais", "anio"], 
                         value_vars=["mujeres","hombres"], 
                         var_name="sexo", 
                         value_name="medallas")

medallero_tidy
# Out:
#               pais  anio     sexo  medallas
# 0   Estados Unidos  2020  mujeres        66
# 1            China  2020  mujeres        37
# 2     Gran Bretaña  2020  mujeres        38
# 3   Estados Unidos  2016  mujeres        61
# 4            China  2016  mujeres        26
# 5     Gran Bretaña  2016  mujeres        27
# 6   Estados Unidos  2012  mujeres        58
# 7            China  2012  mujeres        38
# 8     Gran Bretaña  2012  mujeres        29
# 9   Estados Unidos  2008  mujeres        48
# 10           China  2008  mujeres        34
# 11    Gran Bretaña  2008  mujeres        25
# 12  Estados Unidos  2020  hombres        47
# 13           China  2020  hombres        32
# 14    Gran Bretaña  2020  hombres        26
# 15  Estados Unidos  2016  hombres        60
# 16           China  2016  hombres        18
# 17    Gran Bretaña  2016  hombres        23
# 18  Estados Unidos  2012  hombres        46
# 19           China  2012  hombres        27
# 20    Gran Bretaña  2012  hombres        17
# 21  Estados Unidos  2008  hombres        36
# 22           China  2008  hombres        38
# 23    Gran Bretaña  2008  hombres        19

# %%
medallero_no_tidy
# Out:
#               pais  anio  mujeres  hombres
# 0   Estados Unidos  2020       66       47
# 1            China  2020       37       32
# 2     Gran Bretaña  2020       38       26
# 3   Estados Unidos  2016       61       60
# 4            China  2016       26       18
# 5     Gran Bretaña  2016       27       23
# 6   Estados Unidos  2012       58       46
# 7            China  2012       38       27
# 8     Gran Bretaña  2012       29       17
# 9   Estados Unidos  2008       48       36
# 10           China  2008       34       38
# 11    Gran Bretaña  2008       25       19

# %%
(medallero_no_tidy >> group_by(_.pais) >> summarize(medallas_mujeres = _.mujeres.sum(),
                                                    medallas_hombres = _.hombres.sum())
)
# Out:
#              pais  medallas_mujeres  medallas_hombres
# 0           China               135               115
# 1  Estados Unidos               233               189
# 2    Gran Bretaña               119                85

# %%
(
medallero_tidy >>
    group_by(_.pais,_.sexo) >>
    summarize(tot_medallas = _.medallas.sum())
)
# Out:
#              pais     sexo  tot_medallas
# 0           China  hombres           115
# 1           China  mujeres           135
# 2  Estados Unidos  hombres           189
# 3  Estados Unidos  mujeres           233
# 4    Gran Bretaña  hombres            85
# 5    Gran Bretaña  mujeres           119

# %%
danios_no_tidy.columns
# Out:
# Index(['año', 'daño', 'Robo_total_de_vehículo', 'Robo_parcial_de_vehículo',
#        'Robo_o_asalto_en_calle_o_transporte_público',
#        'Robo_en_casa_habitación', 'Robo_en_forma_distinta_a_las_anteriores',
#        'Amenazas_verbales', 'Extorsión', 'Fraude', 'Lesiones',
#        'Otros_delitos_distintos_a_los_anteriores'],
#       dtype='object')

# %%
danios_tidy = pd.melt(frame=danios_no_tidy, 
                         id_vars=["año", "daño"], 
                         value_vars= ['Robo_total_de_vehículo', 'Robo_parcial_de_vehículo',
       'Robo_o_asalto_en_calle_o_transporte_público',
       'Robo_en_casa_habitación', 'Robo_en_forma_distinta_a_las_anteriores',
       'Amenazas_verbales', 'Extorsión', 'Fraude', 'Lesiones',
       'Otros_delitos_distintos_a_los_anteriores'], 
                         var_name="tipo_delito", 
                         value_name="cantidad_delitos")

# %%
danios_tidy.columns
# Out:
# Index(['año', 'daño', 'tipo_delito', 'cantidad_delitos'], dtype='object')

# %%
danios_tidy >> group_by(_.tipo_delito,_.daño) >> summarize(total_delitos = _.cantidad_delitos.sum()) >> arrange(_.daño)
# Out:
#                                     tipo_delito         daño  total_delitos
# 0                             Amenazas_verbales   económicos        1578820
# 5                                     Extorsión   económicos        4335182
# 10                                       Fraude   económicos       38957751
# 15                                     Lesiones   económicos         690871
# 20     Otros_delitos_distintos_a_los_anteriores   económicos         796250
# 25                      Robo_en_casa_habitación   económicos       15038044
# 30      Robo_en_forma_distinta_a_las_anteriores   económicos       11495963
# 35  Robo_o_asalto_en_calle_o_transporte_público   económicos       67259205
# 40                     Robo_parcial_de_vehículo   económicos       30594590
# 45                       Robo_total_de_vehículo   económicos        4980934
# 1                             Amenazas_verbales  emocionales       17194343
# 6                                     Extorsión  emocionales       29092702
# 11                                       Fraude  emocionales        1807333
# 16                                     Lesiones  emocionales        2937950
# 21     Otros_delitos_distintos_a_los_anteriores  emocionales       12787864
# 26                      Robo_en_casa_habitación  emocionales        2957920
# 31      Robo_en_forma_distinta_a_las_anteriores  emocionales        1039305
# 36  Robo_o_asalto_en_calle_o_transporte_público  emocionales       13876910
# 41                     Robo_parcial_de_vehículo  emocionales         770891
# 46                       Robo_total_de_vehículo  emocionales         561746
# 2                             Amenazas_verbales      físicos        2122227
# 7                                     Extorsión      físicos         316040
# 12                                       Fraude      físicos          62898
# 17                                     Lesiones      físicos        6654736
# 22     Otros_delitos_distintos_a_los_anteriores      físicos         695431
# 27                      Robo_en_casa_habitación      físicos         181482
# 32      Robo_en_forma_distinta_a_las_anteriores      físicos          69647
# 37  Robo_o_asalto_en_calle_o_transporte_público      físicos        2647456
# 42                     Robo_parcial_de_vehículo      físicos          98950
# 47                       Robo_total_de_vehículo      físicos          76766
# 3                             Amenazas_verbales    laborales         439175
# 8                                     Extorsión    laborales         184284
# 13                                       Fraude    laborales          80351
# 18                                     Lesiones    laborales          73118
# 23     Otros_delitos_distintos_a_los_anteriores    laborales         149208
# 28                      Robo_en_casa_habitación    laborales          44277
# 33      Robo_en_forma_distinta_a_las_anteriores    laborales         111021
# 38  Robo_o_asalto_en_calle_o_transporte_público    laborales         329152
# 43                     Robo_parcial_de_vehículo    laborales         137730
# 48                       Robo_total_de_vehículo    laborales          66489
# 4                             Amenazas_verbales      ninguno        9033950
# 9                                     Extorsión      ninguno       33491031
# 14                                       Fraude      ninguno        5331812
# 19                                     Lesiones      ninguno        1049388
# 24     Otros_delitos_distintos_a_los_anteriores      ninguno        2057029
# 29                      Robo_en_casa_habitación      ninguno        3579726
# 34      Robo_en_forma_distinta_a_las_anteriores      ninguno         855193
# 39  Robo_o_asalto_en_calle_o_transporte_público      ninguno        4046268
# 44                     Robo_parcial_de_vehículo      ninguno         816156
# 49                       Robo_total_de_vehículo      ninguno         276453

# %% [markdown]
# Ahora bien, cuando tenemos una tabla en formato no tidy y la transformamos en tidy, los resultados de los summarize suelen presentarse en formato tidy, que como ya sabemos, no es cómodo para nosotros como personas al leer.
#
# Es por eso que existe el proceso inverso: convertir de tabla tidy a no tidy con la función ``pd.pivot()`` .
#
#
# ```python
# ################################################################
# #######    En Python     #######################################
# ################################################################
#
# tabla.pivot(index=["col1","col2",...], # Las columnas que se mantendrán como índice en el DataFrame resultante
#             columns="col", # columna que quieres expandir como encabezados de columnas en el DataFrame ancho.
#             values="col", # columna cuyos valores deseas distribuir en la tabla pivotada.
#            )
#
# tabla.pivot_table(index=["col1","col2",...], # Las columnas que se mantendrán como índice en el DataFrame resultante
#             columns="col", # columna que quieres expandir como encabezados de columnas en el DataFrame ancho.
#             values="col", # columna cuyos valores deseas distribuir en la tabla pivotada.
#            )
# ```

# %%
tabla = pd.DataFrame({
    'Store': ['Store_A', 'Store_A', 'Store_B', 'Store_B'],
    'Product': ['Product_1', 'Product_2', 'Product_1', 'Product_2'],
    'Q1_Sales': [150, 200, 130, 220],
    'Q2_Sales': [180, 210, 160, 230],
    'Q3_Sales': [170, 190, 140, 250],
    'Q4_Sales': [200, 220, 150, 240],
})

tabla
# Out:
#      Store    Product  Q1_Sales  Q2_Sales  Q3_Sales  Q4_Sales
# 0  Store_A  Product_1       150       180       170       200
# 1  Store_A  Product_2       200       210       190       220
# 2  Store_B  Product_1       130       160       140       150
# 3  Store_B  Product_2       220       230       250       240

# %%
tabla_tidy = pd.melt(frame = tabla, 
                     id_vars = ['Store', 'Product'], 
                     value_vars = ['Q1_Sales', 'Q2_Sales', 'Q3_Sales', 'Q4_Sales'],
                     var_name = 'Quarter', 
                     value_name = 'Sales')
tabla_tidy
# Out:
#       Store    Product   Quarter  Sales
# 0   Store_A  Product_1  Q1_Sales    150
# 1   Store_A  Product_2  Q1_Sales    200
# 2   Store_B  Product_1  Q1_Sales    130
# 3   Store_B  Product_2  Q1_Sales    220
# 4   Store_A  Product_1  Q2_Sales    180
# 5   Store_A  Product_2  Q2_Sales    210
# 6   Store_B  Product_1  Q2_Sales    160
# 7   Store_B  Product_2  Q2_Sales    230
# 8   Store_A  Product_1  Q3_Sales    170
# 9   Store_A  Product_2  Q3_Sales    190
# 10  Store_B  Product_1  Q3_Sales    140
# 11  Store_B  Product_2  Q3_Sales    250
# 12  Store_A  Product_1  Q4_Sales    200
# 13  Store_A  Product_2  Q4_Sales    220
# 14  Store_B  Product_1  Q4_Sales    150
# 15  Store_B  Product_2  Q4_Sales    240

# %%
tabla_no_tidy = tabla_tidy.pivot(index=['Store', 'Product'],
                                 columns='Quarter', 
                                 values='Sales') 


tabla_no_tidy
# Out:
# Quarter            Q1_Sales  Q2_Sales  Q3_Sales  Q4_Sales
# Store   Product
# Store_A Product_1       150       180       170       200
#         Product_2       200       210       190       220
# Store_B Product_1       130       160       140       150
#         Product_2       220       230       250       240

# %%
tabla_no_tidy.reset_index()
# Out:
# Quarter    Store    Product  Q1_Sales  Q2_Sales  Q3_Sales  Q4_Sales
# 0        Store_A  Product_1       150       180       170       200
# 1        Store_A  Product_2       200       210       190       220
# 2        Store_B  Product_1       130       160       140       150
# 3        Store_B  Product_2       220       230       250       240

# %%
tabla_tidy.pivot(index=['Store', 'Product'],
                                 columns='Quarter', 
                                 values='Sales') >> _.reset_index()
# Out:
# Quarter    Store    Product  Q1_Sales  Q2_Sales  Q3_Sales  Q4_Sales
# 0        Store_A  Product_1       150       180       170       200
# 1        Store_A  Product_2       200       210       190       220
# 2        Store_B  Product_1       130       160       140       150
# 3        Store_B  Product_2       220       230       250       240
